# %%
import gym
from gym import Env # env superclass
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete

import numpy as np
import random
import os
import warnings

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ## Space Types

# %%
warnings.filterwarnings("ignore")

# %%
Discrete(3).sample() # exmaple of discrete spaces, here we have 0 1 2, you can map to each action
# Out:
# 0

# %%
Box(low=0, high=1, shape=(3,)).sample() # 3x1
Box(low=0, high=1, shape=(3,3)).sample() # ex for continuous variables, 3x3
# Out:
# array([[0.25859082, 0.1462454 , 0.43991354],
#        [0.89556605, 0.7572077 , 0.5663108 ],
#        [0.58212054, 0.19536789, 0.6777912 ]], dtype=float32)

# %%
Tuple((Discrete(3), Box(0,1,(3,)))).sample # combined
# Out:
# <bound method Tuple.sample of Tuple(Discrete(3), Box(0.0, 1.0, (3,), float32))>

# %%
Dict({
    'height':Discrete(2),
    'speed':Box(0,100,shape=(1,)),
    'color':MultiDiscrete([255,255,255])
    }).sample()
# Out:
# OrderedDict([('color', array([ 80,  11, 233], dtype=int64)),
#              ('height', 0),
#              ('speed', array([33.887768], dtype=float32))])

# %%
MultiBinary(12).sample() # Multiple binary values (0, 1)
# Out:
# array([0, 0, 0, 0, 1, 0, 1, 0, 1, 1, 1, 1], dtype=int8)

# %%
MultiDiscrete([100000, 1000, 10]).sample() # Multiple discrete values
# Out:
# array([91440,   532,     6], dtype=int64)

# %% [markdown]
# ## Custom Env
# - Agent to give best shower (temp) possible
# - Temp is going to fluctuate (people in building)
# - Optimal temp is 37-39 degrees (it needs to learn to get to this conclusion)

# %%
from gym import Env

class Skeleton(Env):
    
    def __init__(self):
        self.action_space = None
        self.observation_space = None
        
    def step(self, action):
        pass
    
    def render(self):
        pass
    
    def reset(self):
        pass

# %%
from gym import Env

class ShowerEnv(Env):
    
    def __init__(self):
        # actions
        self.action_space = Discrete(3) # Tap up, down, or hold
        
        # happening
        self.observation_space = Box(low=np.array([0]), high=np.array([100])) # Observation space is between temps of 0-100
        
        # initial state 38 +- 3, agent has to get range of 37-39
        self.state = 38 + random.randint(-3,3)
        
        # episode lenght, 60 sec shower, every action -1
        self.shower_lenght = 60
        
    def step(self, action):
        # Apply temp object, action passed in changes the space
        self.state += action-1
        
        # Shower time decrease
        self.shower_lenght -= 1
        
        # Culculate Reward
        if self.state >= 37 and self.state <= 39:
            reward = 1
        else:
            reward = -1
            
        if self.shower_lenght <= 0:
            terminated = True
        else:
            terminated = False
            
        info = {}
        
        return self.state, reward, terminated, info # returns: observation, reward, terminated and info        
    
    def render(self):
        pass # we can leave it for now
    
    def reset(self):
        self.state = np.array([38+random.randint(-3,3)]).astype(float)
        self.shower_lenght = 60
        return self.state # return observation

# %%
env = ShowerEnv()

# %%
env.action_space
# Out:
# Discrete(3)

# %%
env.observation_space.sample()
# Out:
# array([58.742447], dtype=float32)

# %% [markdown]
# ## EnvTest

# %%
for episode in range(5):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        action = env.action_space.sample() # random random sample
        obs, reward, done, info = env.step(action)
        
        score += reward
        
    print(f'Ep: {episode}, Score" {score}')
    
    env.close()
# Out:
# Ep: 0, Score" -52
# Ep: 1, Score" -38
# Ep: 2, Score" -60
# Ep: 3, Score" -42
# Ep: 4, Score" -32

# %%
env.close()

# %%
env??
# Out:
# Type:            ShowerEnv
# String form:     <ShowerEnv instance>
# Docstring:       <no docstring>
# Class docstring:
# The main OpenAI Gym class.
#
# It encapsulates an environment with arbitrary behind-the-scenes dynamics.
# An environment can be partially or fully observed.
#
# The main API methods that users of this class need to know are:
#
# - :meth:`step` - Takes a step in the environment using an action returning the next observation, reward,
#   if the environment terminated and observation information.
# - :meth:`reset` - Resets the environment to an initial state, returning the initial observation and observation information.
# - :meth:`render` - Renders the environment observation with modes depending on the output
# - :meth:`close` - Closes the environment, important for rendering where pygame is imported
#
# And set the following attributes:
#
# - :attr:`action_space` - The Space object corresponding to valid actions
# - :attr:`observation_space` - The Space object corresponding to valid observations
# - :attr:`reward_range` - A tuple corresponding to the minimum and maximum possible rewards
# - :attr:`spec` - An environment spec that contains the information used to initialise the environment from `gym.make`
# - :attr:`metadata` - The metadata of the environment, i.e. render modes
# - :attr:`np_random` - The random number generator for the environment
#
# Note: a default reward range set to :math:`(-\infty,+\infty)` already exists. Set it if you want a narrower range.

# %% [markdown]
# ## Train Model

# %%
log_path = 'logs'

# %%
model = PPO('MlpPolicy', env, tensorboard_log=log_path, device='cuda', verbose=1)
model.learn(200_000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -26.3    |
# | time/              |          |
# |    fps             | 738      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -26.3        |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0083359955 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000103    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.2         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 65.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.9       |
# | time/                   |             |
# |    fps                  | 533         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011643159 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000394    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00595    |
# |    value_loss           | 53.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -28.7      |
# | time/                   |            |
# |    fps                  | 518        |
# |    iterations           | 4          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00877778 |
# |    clip_fraction        | 0.0289     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -0.00146   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 36.1       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00158   |
# |    value_loss           | 69.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -30          |
# | time/                   |              |
# |    fps                  | 503          |
# |    iterations           | 5            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0096231485 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 4.43e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.6         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 63           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -30.2        |
# | time/                   |              |
# |    fps                  | 498          |
# |    iterations           | 6            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0109148845 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.000169     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.5         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00842     |
# |    value_loss           | 74.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.5       |
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 7           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010286244 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.00426    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.8        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00905    |
# |    value_loss           | 72.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -25.4      |
# | time/                   |            |
# |    fps                  | 496        |
# |    iterations           | 8          |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00843458 |
# |    clip_fraction        | 0.0764     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | -1.43e-05  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 40.8       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00496   |
# |    value_loss           | 81.9       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -20.5       |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 9           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008680867 |
# |    clip_fraction        | 0.0651      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | -4.7e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.8        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 79.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -19          |
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 10           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0035513814 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.985       |
# |    explained_variance   | 7.75e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.1         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 87.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -20.2        |
# | time/                   |              |
# |    fps                  | 500          |
# |    iterations           | 11           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0091302935 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.981       |
# |    explained_variance   | 6.78e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.4         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00874     |
# |    value_loss           | 69.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -21.5        |
# | time/                   |              |
# |    fps                  | 496          |
# |    iterations           | 12           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0073976843 |
# |    clip_fraction        | 0.0666       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.971       |
# |    explained_variance   | -0.00678     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.8         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00467     |
# |    value_loss           | 79.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -19.7       |
# | time/                   |             |
# |    fps                  | 495         |
# |    iterations           | 13          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008552458 |
# |    clip_fraction        | 0.0463      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.905      |
# |    explained_variance   | -0.00268    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 91.7        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -16.7         |
# | time/                   |               |
# |    fps                  | 493           |
# |    iterations           | 14            |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00029282732 |
# |    clip_fraction        | 0.00195       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.906        |
# |    explained_variance   | 0.00445       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 39.4          |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000197     |
# |    value_loss           | 81.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -19.1        |
# | time/                   |              |
# |    fps                  | 490          |
# |    iterations           | 15           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0067693144 |
# |    clip_fraction        | 0.0863       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.914       |
# |    explained_variance   | 0.0152       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.2         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00678     |
# |    value_loss           | 90.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -21.7        |
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 16           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0033364678 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.925       |
# |    explained_variance   | -0.0135      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.3         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000212    |
# |    value_loss           | 69.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -18        |
# | time/                   |            |
# |    fps                  | 486        |
# |    iterations           | 17         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.00724775 |
# |    clip_fraction        | 0.114      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.91      |
# |    explained_variance   | 0.00327    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 46.2       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00736   |
# |    value_loss           | 90.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -16.1       |
# | time/                   |             |
# |    fps                  | 487         |
# |    iterations           | 18          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004177574 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | -0.00774    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.6        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.000515    |
# |    value_loss           | 93          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -15.5        |
# | time/                   |              |
# |    fps                  | 487          |
# |    iterations           | 19           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0025484448 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.865       |
# |    explained_variance   | 0.00877      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.5         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 83.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -16.3       |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 20          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007331381 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.0391      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00755    |
# |    value_loss           | 89.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -10.8        |
# | time/                   |              |
# |    fps                  | 485          |
# |    iterations           | 21           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0042337114 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.837       |
# |    explained_variance   | 0.0145       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.3         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00259     |
# |    value_loss           | 74.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -11.3        |
# | time/                   |              |
# |    fps                  | 482          |
# |    iterations           | 22           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0057416228 |
# |    clip_fraction        | 0.0733       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.812       |
# |    explained_variance   | -0.0816      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.4         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 76.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -8.64       |
# | time/                   |             |
# |    fps                  | 481         |
# |    iterations           | 23          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004490763 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.804      |
# |    explained_variance   | 0.00867     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35          |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000146   |
# |    value_loss           | 71.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -8.76        |
# | time/                   |              |
# |    fps                  | 481          |
# |    iterations           | 24           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0033707523 |
# |    clip_fraction        | 0.0501       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.799       |
# |    explained_variance   | -0.0149      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.9         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 81.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -6.68       |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 25          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.001652026 |
# |    clip_fraction        | 0.00859     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | -0.00682    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.9        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 7.49e-05    |
# |    value_loss           | 91.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -10.2       |
# | time/                   |             |
# |    fps                  | 482         |
# |    iterations           | 26          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006428931 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.791      |
# |    explained_variance   | -0.00162    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.3        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00859    |
# |    value_loss           | 77.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -11.8        |
# | time/                   |              |
# |    fps                  | 481          |
# |    iterations           | 27           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0030246172 |
# |    clip_fraction        | 0.0235       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.787       |
# |    explained_variance   | -0.0176      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.4         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 79.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -13.5       |
# | time/                   |             |
# |    fps                  | 483         |
# |    iterations           | 28          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004960288 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.774      |
# |    explained_variance   | 0.0815      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35          |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 76.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -10.5        |
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 29           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0021068864 |
# |    clip_fraction        | 0.00376      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.776       |
# |    explained_variance   | -0.0433      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.2         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00045     |
# |    value_loss           | 71.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -8.24        |
# | time/                   |              |
# |    fps                  | 483          |
# |    iterations           | 30           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0044966023 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.71        |
# |    explained_variance   | 0.0409       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.2         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00099     |
# |    value_loss           | 74.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -3.24        |
# | time/                   |              |
# |    fps                  | 481          |
# |    iterations           | 31           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0029320894 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.689       |
# |    explained_variance   | 0.056        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 40.9         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.00015      |
# |    value_loss           | 85.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -2.66        |
# | time/                   |              |
# |    fps                  | 479          |
# |    iterations           | 32           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0035688872 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.655       |
# |    explained_variance   | 0.0776       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.4         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 71.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -4.16        |
# | time/                   |              |
# |    fps                  | 478          |
# |    iterations           | 33           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0007043398 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.643       |
# |    explained_variance   | 0.0238       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.1         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000494    |
# |    value_loss           | 76.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -8.04       |
# | time/                   |             |
# |    fps                  | 477         |
# |    iterations           | 34          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.002570372 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | 0.0892      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.1        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00105    |
# |    value_loss           | 83.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -8.2         |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 35           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0071636634 |
# |    clip_fraction        | 0.0958       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.631       |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.6         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000835    |
# |    value_loss           | 68.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -3.68       |
# | time/                   |             |
# |    fps                  | 475         |
# |    iterations           | 36          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.002374583 |
# |    clip_fraction        | 0.071       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.7        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.000884   |
# |    value_loss           | 84.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 7.04        |
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 37          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.001866546 |
# |    clip_fraction        | 0.0195      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.552      |
# |    explained_variance   | 0.0413      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39          |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00135    |
# |    value_loss           | 83.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 6.6          |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 38           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0031810529 |
# |    clip_fraction        | 0.0605       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.52        |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46           |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.00801      |
# |    value_loss           | 73.2         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 8.9           |
# | time/                   |               |
# |    fps                  | 470           |
# |    iterations           | 39            |
# |    time_elapsed         | 169           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00035407516 |
# |    clip_fraction        | 0.0282        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.493        |
# |    explained_variance   | 0.175         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 42.6          |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000436     |
# |    value_loss           | 87.9          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 2.88         |
# | time/                   |              |
# |    fps                  | 469          |
# |    iterations           | 40           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0014602228 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.452       |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.2         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 90.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 3.56         |
# | time/                   |              |
# |    fps                  | 469          |
# |    iterations           | 41           |
# |    time_elapsed         | 179          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0059419842 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.45        |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.1         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000872    |
# |    value_loss           | 81.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -1.98        |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 42           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0006479353 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.448       |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.7         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000748     |
# |    value_loss           | 90.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.44        |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 43          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.006465324 |
# |    clip_fraction        | 0.0311      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.47       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.5        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.000121    |
# |    value_loss           | 96.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 3.02        |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 44          |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.003908434 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.285       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.2        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00267    |
# |    value_loss           | 81.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 7.06         |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 45           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0018458783 |
# |    clip_fraction        | 0.0461       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.496       |
# |    explained_variance   | 0.127        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.6         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 76.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -12.3       |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 46          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.116028026 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.7        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0013      |
# |    value_loss           | 84.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -19.9       |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 47          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.025791299 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.445      |
# |    explained_variance   | -0.446      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00141    |
# |    value_loss           | 44.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -31.4        |
# | time/                   |              |
# |    fps                  | 470          |
# |    iterations           | 48           |
# |    time_elapsed         | 208          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0030118364 |
# |    clip_fraction        | 0.0584       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.322       |
# |    explained_variance   | 0.396        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.3         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00368     |
# |    value_loss           | 81.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -17.3        |
# | time/                   |              |
# |    fps                  | 469          |
# |    iterations           | 49           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0020481783 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.298       |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.5         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00521     |
# |    value_loss           | 91.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -15.4        |
# | time/                   |              |
# |    fps                  | 471          |
# |    iterations           | 50           |
# |    time_elapsed         | 217          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0005334222 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.281       |
# |    explained_variance   | 0.402        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.6         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 92.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -11.7       |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 51          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.002180384 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.261      |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.9        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00165    |
# |    value_loss           | 107         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -10.8        |
# | time/                   |              |
# |    fps                  | 472          |
# |    iterations           | 52           |
# |    time_elapsed         | 225          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0018805815 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.256       |
# |    explained_variance   | 0.509        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49           |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0049      |
# |    value_loss           | 105          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -7.64         |
# | time/                   |               |
# |    fps                  | 472           |
# |    iterations           | 53            |
# |    time_elapsed         | 229           |
# |    total_timesteps      | 108544        |
# | train/                  |               |
# |    approx_kl            | 0.00082362164 |
# |    clip_fraction        | 0.0266        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.264        |
# |    explained_variance   | 0.46          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 57.6          |
# |    n_updates            | 520           |
# |    policy_gradient_loss | 0.00736       |
# |    value_loss           | 111           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -10.9         |
# | time/                   |               |
# |    fps                  | 472           |
# |    iterations           | 54            |
# |    time_elapsed         | 234           |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 0.00084855733 |
# |    clip_fraction        | 0.0121        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.224        |
# |    explained_variance   | 0.511         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 54.5          |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.000944     |
# |    value_loss           | 111           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# ...
# |    time_elapsed         | 395          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0007459939 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.227       |
# |    explained_variance   | 0.611        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.9         |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 128          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 5.66         |
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 82           |
# |    time_elapsed         | 405          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0011437074 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | 0.717        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.1         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | 0.00388      |
# |    value_loss           | 108          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 3.32         |
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 83           |
# |    time_elapsed         | 415          |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0060854633 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.9         |
# |    n_updates            | 820          |
# |    policy_gradient_loss | 0.0056       |
# |    value_loss           | 106          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 7.22        |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 84          |
# |    time_elapsed         | 423         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.002396732 |
# |    clip_fraction        | 0.0205      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.194      |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.5        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | 0.00203     |
# |    value_loss           | 119         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 0.68         |
# | time/                   |              |
# |    fps                  | 403          |
# |    iterations           | 85           |
# |    time_elapsed         | 431          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0099548735 |
# |    clip_fraction        | 0.0237       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.196       |
# |    explained_variance   | 0.728        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.6         |
# |    n_updates            | 840          |
# |    policy_gradient_loss | 0.00794      |
# |    value_loss           | 108          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -5.2          |
# | time/                   |               |
# |    fps                  | 401           |
# |    iterations           | 86            |
# |    time_elapsed         | 438           |
# |    total_timesteps      | 176128        |
# | train/                  |               |
# |    approx_kl            | 0.00042173069 |
# |    clip_fraction        | 0.0152        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.151        |
# |    explained_variance   | 0.703         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 39.3          |
# |    n_updates            | 850           |
# |    policy_gradient_loss | 0.00217       |
# |    value_loss           | 94.5          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -11.4       |
# | time/                   |             |
# |    fps                  | 399         |
# |    iterations           | 87          |
# |    time_elapsed         | 446         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.014094366 |
# |    clip_fraction        | 0.0228      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.141      |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.6        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | 0.018       |
# |    value_loss           | 124         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -10.6        |
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 88           |
# |    time_elapsed         | 455          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0020805588 |
# |    clip_fraction        | 0.0063       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0999      |
# |    explained_variance   | 0.73         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 58.5         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000761    |
# |    value_loss           | 109          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -5.88        |
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 89           |
# |    time_elapsed         | 459          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0003307835 |
# |    clip_fraction        | 0.00435      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.106       |
# |    explained_variance   | 0.782        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66           |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.000145    |
# |    value_loss           | 107          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 0.74         |
# | time/                   |              |
# |    fps                  | 396          |
# |    iterations           | 90           |
# |    time_elapsed         | 464          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0007433916 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.122       |
# |    explained_variance   | 0.764        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 68.3         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | 0.000163     |
# |    value_loss           | 113          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 4.78          |
# | time/                   |               |
# |    fps                  | 396           |
# |    iterations           | 91            |
# |    time_elapsed         | 469           |
# |    total_timesteps      | 186368        |
# | train/                  |               |
# |    approx_kl            | 0.00019860987 |
# |    clip_fraction        | 0.0104        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.135        |
# |    explained_variance   | 0.725         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 62.1          |
# |    n_updates            | 900           |
# |    policy_gradient_loss | 0.00115       |
# |    value_loss           | 114           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 8.5           |
# | time/                   |               |
# |    fps                  | 394           |
# |    iterations           | 92            |
# |    time_elapsed         | 477           |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 0.00029970045 |
# |    clip_fraction        | 0.0109        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.152        |
# |    explained_variance   | 0.722         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 55.1          |
# |    n_updates            | 910           |
# |    policy_gradient_loss | 0.000183      |
# |    value_loss           | 119           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | 10.1          |
# | time/                   |               |
# |    fps                  | 392           |
# |    iterations           | 93            |
# |    time_elapsed         | 484           |
# |    total_timesteps      | 190464        |
# | train/                  |               |
# |    approx_kl            | 0.00062684505 |
# |    clip_fraction        | 0.0165        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.153        |
# |    explained_variance   | 0.707         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 73.2          |
# |    n_updates            | 920           |
# |    policy_gradient_loss | 0.00214       |
# |    value_loss           | 130           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 4.44        |
# | time/                   |             |
# |    fps                  | 385         |
# |    iterations           | 94          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.002223874 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.166      |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.7        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | 0.00217     |
# |    value_loss           | 120         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -4.38        |
# | time/                   |              |
# |    fps                  | 374          |
# |    iterations           | 95           |
# |    time_elapsed         | 519          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0005913109 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.158       |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67           |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 131          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 60            |
# |    ep_rew_mean          | -12.6         |
# | time/                   |               |
# |    fps                  | 375           |
# |    iterations           | 96            |
# |    time_elapsed         | 524           |
# |    total_timesteps      | 196608        |
# | train/                  |               |
# |    approx_kl            | 0.00059368764 |
# |    clip_fraction        | 0.0138        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.152        |
# |    explained_variance   | 0.743         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 48.5          |
# |    n_updates            | 950           |
# |    policy_gradient_loss | 0.00078       |
# |    value_loss           | 130           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -14.6        |
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 97           |
# |    time_elapsed         | 529          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0012189095 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.209       |
# |    explained_variance   | 0.687        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.6         |
# |    n_updates            | 960          |
# |    policy_gradient_loss | 3.76e-07     |
# |    value_loss           | 142          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -16.8        |
# | time/                   |              |
# |    fps                  | 375          |
# |    iterations           | 98           |
# |    time_elapsed         | 534          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0004176415 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.186       |
# |    explained_variance   | 0.678        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 93.9         |
# |    n_updates            | 970          |
# |    policy_gradient_loss | 0.00178      |
# |    value_loss           | 153          |
# ------------------------------------------

# %%
model.save('models\\showe_model_PPO')
evaluate_policy(model, env, n_eval_episodes=10, render=False)
# Out:
# (-36.0, 48.0)
